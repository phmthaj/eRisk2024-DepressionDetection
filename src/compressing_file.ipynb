# %%
import os, re, glob, itertools
import pyarrow as pa, pyarrow.parquet as pq

FOLDER = r"C:\Users\thaip\Desktop\eRisk\erisk2024" 
OUT_PARQUET = "erisk24_all_trec.parquet"

DOC_RE = re.compile(r"<DOC>(.*?)</DOC>", flags=re.DOTALL | re.IGNORECASE)
def get_tag(block, tag):
    m = re.search(rf"<\s*{tag}\s*>(.*?)</\s*{tag}\s*>", block,
                  flags=re.DOTALL | re.IGNORECASE)
    return m.group(1).strip() if m else None

def parse_file(path):
    with open(path, "r", encoding="utf-8", errors="ignore") as f:
        content = f.read()
    rows = []
    for blk in DOC_RE.findall(content):
        rows.append((
            get_tag(blk, "DOCNO"),
            get_tag(blk, "PRE"),
            get_tag(blk, "TEXT"),
            get_tag(blk, "POST"),
            os.path.basename(path),
        ))
    return rows

files = glob.glob(os.path.join(FOLDER, "**", "*.trec"), recursive=True)

schema = pa.schema([
    ("docno", pa.string()),
    ("pre", pa.string()),
    ("text", pa.string()),
    ("post", pa.string()),
    ("source_file", pa.string()),
])

writer = None
BATCH = 400  
for i in range(0, len(files), BATCH):
    chunk = files[i:i+BATCH]
    batch_rows = list(itertools.chain.from_iterable(parse_file(p) for p in chunk))
    if not batch_rows: 
        continue
    table = pa.Table.from_pylist(
        [dict(docno=a, pre=b, text=c, post=d, source_file=e) for (a,b,c,d,e) in batch_rows],
        schema=schema,
    )
    if writer is None:
        writer = pq.ParquetWriter(OUT_PARQUET, schema)
    writer.write_table(table)
if writer:
    writer.close()

print("Wrote:", OUT_PARQUET)
# Out:
# Wrote: erisk24_all_trec.parquet

# %%
import pandas as pd

df = pd.read_parquet("erisk24_all_trec.parquet")

print(len(df))         
print(df.columns)       
print(df.head())
# Out:
# 15542200
# Index(['docno', 'pre', 'text', 'post', 'source_file'], dtype='object')
#    docno                                                pre  \
# 0  0_0_0
# 1  0_0_1
# 2  0_0_2  I met someone who understands me better than I...
# 3  0_0_3  Our friendship thus far is completely platonic...
# 4  0_0_4  I tried to break up with my sweet SO, saying t...
#
#                                                 text  \
# 0       I guess it depends on what cheating entails.
# 1  I met someone who understands me better than I...
# 2  Our friendship thus far is completely platonic...
# 3  I tried to break up with my sweet SO, saying t...
# 4  It's been a year but it's noticeable he's stil...
#
#                                                 post source_file
# 0  I met someone who understands me better than I...    s_0.trec
# 1  Our friendship thus far is completely platonic...    s_0.trec
# 2  I tried to break up with my sweet SO, saying t...    s_0.trec
# 3  It's been a year but it's noticeable he's stil...    s_0.trec
# 4  Although most wouldn't consider it cheating, I...    s_0.trec

# %%
df.to_csv("erisk24_clean.csv", index=False, encoding="utf-8")

# %%
PARQUET_PATH = "erisk24_all_trec.parquet"  
import duckdb
import pandas as pd

con = duckdb.connect()
con.execute(f"""
CREATE OR REPLACE VIEW docs AS 
SELECT * FROM read_parquet('{PARQUET_PATH}');
""")

overview = con.execute("""
SELECT 
  COUNT(*) AS n_rows,
  SUM(CASE WHEN length(trim(post))>0 THEN 1 ELSE 0 END)*1.0/COUNT(*) AS ratio_post_nonempty,
  AVG(length(text))  AS avg_len_text,
  MEDIAN(length(text)) AS med_len_text
FROM docs
""").df()
display(overview)

peek = con.execute("""
SELECT docno, pre, text, post, source_file
FROM docs
LIMIT 10
""").df()
display(peek)

src_count = con.execute("""
SELECT source_file, COUNT(*) AS n
FROM docs
GROUP BY source_file
ORDER BY n DESC
LIMIT 20
""").df()
display(src_count)

nulls = con.execute("""
SELECT
  SUM(CASE WHEN text IS NULL OR length(trim(text))=0 THEN 1 ELSE 0 END) AS empty_text,
  SUM(CASE WHEN post IS NULL OR length(trim(post))=0 THEN 1 ELSE 0 END) AS empty_post
FROM docs
""").df()
display(nulls)

dups = con.execute("""
SELECT docno, COUNT(*) AS c
FROM docs
GROUP BY docno
HAVING COUNT(*)>1
ORDER BY c DESC
LIMIT 20
""").df()
display(dups)
# Out:
#      n_rows  ratio_post_nonempty  avg_len_text  med_len_text
# 0  15542200             0.944578     93.319207          81.0
#    docno                                                pre  \
# 0  0_0_0
# 1  0_0_1
# 2  0_0_2  I met someone who understands me better than I...
# 3  0_0_3  Our friendship thus far is completely platonic...
# 4  0_0_4  I tried to break up with my sweet SO, saying t...
# 5  0_0_5  It's been a year but it's noticeable he's stil...
# 6  0_0_6  Although most wouldn't consider it cheating, I...
# 7  0_0_7  I will not tell my SO because he would read fu...
# 8  0_0_8  I'm trying to work on breaking it off, but my ...
# 9  1_0_0
#
#                                                 text  \
# 0       I guess it depends on what cheating entails.
# 1  I met someone who understands me better than I...
# 2  Our friendship thus far is completely platonic...
# 3  I tried to break up with my sweet SO, saying t...
# 4  It's been a year but it's noticeable he's stil...
# 5  Although most wouldn't consider it cheating, I...
# 6  I will not tell my SO because he would read fu...
# 7  I'm trying to work on breaking it off, but my ...
# 8                          **tl;dr** I'm confused. )
# 9  Just found out my boyfriend of 3 years has bee...
#
#                                                 post source_file
# 0  I met someone who understands me better than I...    s_0.trec
# 1  Our friendship thus far is completely platonic...    s_0.trec
# 2  I tried to break up with my sweet SO, saying t...    s_0.trec
# 3  It's been a year but it's noticeable he's stil...    s_0.trec
# 4  Although most wouldn't consider it cheating, I...    s_0.trec
# 5  I will not tell my SO because he would read fu...    s_0.trec
# 6  I'm trying to work on breaking it off, but my ...    s_0.trec
# 7                          **tl;dr** I'm confused. )    s_0.trec
# 8                                                       s_0.trec
# 9                       I am completely heartbroken.    s_1.trec
#    source_file      n
# 0   s_162.trec  44465
# 1   s_282.trec  36080
# 2   s_222.trec  34456
# 3   s_445.trec  33505
# 4   s_387.trec  33217
# 5   s_523.trec  32447
# 6   s_252.trec  32333
# 7   s_510.trec  32286
# 8   s_478.trec  32038
# 9   s_209.trec  32018
# 10  s_123.trec  31982
# 11  s_285.trec  31907
# 12  s_507.trec  31861
# 13  s_438.trec  31673
# 14  s_266.trec  31672
# 15  s_499.trec  31600
# 16  s_479.trec  31580
# 17  s_206.trec  31560
# 18  s_513.trec  31389
# 19  s_114.trec  31365
#    empty_text  empty_post
# 0       338.0    861379.0
# Empty DataFrame
# Columns: [docno, c]
# Index: []

# %%
peek
# Out:
#    docno                                                pre  \
# 0  0_0_0
# 1  0_0_1
# 2  0_0_2  I met someone who understands me better than I...
# 3  0_0_3  Our friendship thus far is completely platonic...
# 4  0_0_4  I tried to break up with my sweet SO, saying t...
# 5  0_0_5  It's been a year but it's noticeable he's stil...
# 6  0_0_6  Although most wouldn't consider it cheating, I...
# 7  0_0_7  I will not tell my SO because he would read fu...
# 8  0_0_8  I'm trying to work on breaking it off, but my ...
# 9  1_0_0
#
#                                                 text  \
# 0       I guess it depends on what cheating entails.
# 1  I met someone who understands me better than I...
# 2  Our friendship thus far is completely platonic...
# 3  I tried to break up with my sweet SO, saying t...
# 4  It's been a year but it's noticeable he's stil...
# 5  Although most wouldn't consider it cheating, I...
# 6  I will not tell my SO because he would read fu...
# 7  I'm trying to work on breaking it off, but my ...
# 8                          **tl;dr** I'm confused. )
# 9  Just found out my boyfriend of 3 years has bee...
#
#                                                 post source_file
# 0  I met someone who understands me better than I...    s_0.trec
# 1  Our friendship thus far is completely platonic...    s_0.trec
# 2  I tried to break up with my sweet SO, saying t...    s_0.trec
# 3  It's been a year but it's noticeable he's stil...    s_0.trec
# 4  Although most wouldn't consider it cheating, I...    s_0.trec
# 5  I will not tell my SO because he would read fu...    s_0.trec
# 6  I'm trying to work on breaking it off, but my ...    s_0.trec
# 7                          **tl;dr** I'm confused. )    s_0.trec
# 8                                                       s_0.trec
# 9                       I am completely heartbroken.    s_1.trec

# %%
df1 = pd.read_csv("majority_erisk_2024.csv")
df1.head()
# Out:
#      1\t0\t98174_0_14\t0
# 0  1\t0\t506920_0_136\t0
# 1   1\t0\t347157_0_22\t1
# 2    1\t0\t363323_4_6\t0
# 3   1\t0\t496450_0_24\t1
# 4   1\t0\t305077_0_32\t0

# %%
import pandas as pd

IN_TSV  = "majority_erisk_2024.csv"           
OUT_CSV = "majority_erisk_24_clean.csv"      

df = pd.read_csv(IN_TSV, sep="\t", header=None,
                 names=["query", "_drop", "doc_id", "relevant"])

df = df.drop(columns=["_drop"])

df["query"] = pd.to_numeric(df["query"], errors="coerce").astype("Int64")
df["doc_id"] = df["doc_id"].astype(str).str.strip()

df["relevant"] = (
    df["relevant"].astype(str).str.strip().str.lower()
      .map({"1":1, "0":0, "true":1, "false":0, "t":1, "y":1, "yes":1, "n":0, "no":0})
      .astype("Int8")
)

df.to_csv(OUT_CSV, index=False, encoding="utf-8")
print("Wrote:", OUT_CSV)
print(df.head())
# Out:
# Wrote: majority_erisk_24_clean.csv
#    query        doc_id  relevant
# 0      1    98174_0_14         0
# 1      1  506920_0_136         0
# 2      1   347157_0_22         1
# 3      1    363323_4_6         0
# 4      1   496450_0_24         1

# %%
import duckdb

PARQUET_PATH = "erisk24_all_trec.parquet"       # parquet chứa DOCs
QRELS_CSV    = "majority_erisk_24_clean.csv"    # file CSV sạch
OUT_PARQUET  = "dataset2024.parquet"            # output sau join

con = duckdb.connect()

con.execute(f"""
CREATE OR REPLACE VIEW docs AS
SELECT * FROM read_parquet('{PARQUET_PATH}');
""")

con.execute(f"""
CREATE OR REPLACE VIEW qrels_raw AS
SELECT * FROM read_csv_auto('{QRELS_CSV}', HEADER=TRUE);
""")

con.execute("""
CREATE OR REPLACE VIEW qrels AS
SELECT
  CAST(query AS INTEGER) AS query,
  TRIM(CAST(doc_id AS VARCHAR)) AS docno,   -- đổi tên để join
  CASE 
    WHEN UPPER(CAST(relevant AS VARCHAR)) IN ('TRUE','T','1','YES','Y') THEN TRUE
    ELSE FALSE
  END AS relevant
FROM qrels_raw;
""")

check = con.execute("""
SELECT 
  (SELECT COUNT(*) FROM qrels) AS qrels_rows,
  (SELECT COUNT(*) FROM docs)  AS docs_rows,
  (SELECT COUNT(*) FROM qrels q JOIN docs d USING(docno)) AS matched_rows,
  (SELECT COUNT(*) FROM qrels q LEFT JOIN docs d USING(docno) WHERE d.docno IS NULL) AS qrels_not_found
""").df()
print(check)

con.execute(f"""
COPY (
  SELECT
    q.query,
    q.docno,
    q.relevant,
    d.pre,
    d.text,
    d.post,
    d.source_file
  FROM qrels q
  JOIN docs d USING (docno)
) TO '{OUT_PARQUET}' (FORMAT PARQUET, COMPRESSION ZSTD);
""")

print(OUT_PARQUET)
# Out:
#    qrels_rows  docs_rows  matched_rows  qrels_not_found
# 0       14823   15542200         14823                0
# dataset2024.parquet

# %%
con = duckdb.connect()
real_path = "dataset2024.parquet"

# %%
con.execute(f"""
CREATE OR REPLACE VIEW docs AS 
SELECT * FROM read_parquet('{real_path}');
""")

# %%
peek = con.execute("""
SELECT *
FROM docs
LIMIT 20
""").df()
display(peek)
# Out:
#     query       docno  relevant  \
# 0      19  98002_0_18     False
# 1      11   98004_0_2      True
# 2      17   98004_0_6     False
# 3      18  98006_0_22     False
# 4      18  98006_0_26     False
# 5      19  98006_1_43     False
# 6      19   98011_0_4      True
# 7      19  98011_0_15     False
# 8      16   98013_0_0      True
# 9      16   98013_0_6     False
# 10     17   98013_0_8     False
# 11     16  98013_0_23     False
# 12     21  98022_0_45      True
# 13     14  98034_0_36      True
# 14     19   98038_0_0     False
# 15     14   98040_1_7     False
# 16     17  98041_0_20     False
# 17     17  98044_0_10     False
# 18     20   98058_0_3      True
# 19     14   98058_0_5     False
#
#                                                   pre  \
# 0   I also wouldn't mind a few people to talk to a...
# 1   When I was being prepped for surgery, the nurs...
# 2   She started wheeling me down to surgery and ke...
# 3   That's when it will really set in that the who...
# 4   **TL;DR:** People are skinny because they don'...
# 5   The closest I could be while still making out ...
# 6   I already decided to do all i can and focus on...
# 7                               I fucked up my tests.
# 8
# 9   All that existed was my eyes and the deafening...
# 10  I shit you not i regressed to the childhood na...
# 11             I am very intrigued by this phenomena.
# 12  I want her to feel comfortable, but at the sam...
# 13               He obviously never really liked me!'
# 14
# 15                              TL;DR we're good now.
# 16  I could tell he was definitely interested in m...
# 17  I assured her that what ever happens,  happens...
# 18  I couldn't see because the headaches were so b...
# 19  Then I develop a stomach bug, when it hurts to...
#
#                                                  text  \
# 0                          Get my mind off of things.
# 1                              and I became agitated.
# 2                                        Feeling it?"
# 3   That's when he will realize that he really doe...
# 4   If you are skinny it's because you don't eat e...
# 5   I could not see anything except two red dots l...
# 6                       But I can find no clear mind.
# 7                         Dont know how to focus now.
# 8                                 My sleep paralysis.
# 9   When i came to there were three very intense f...
# 10  My paralysis is ALWAYS accompanied  by the mos...
# 11  TL;DR  my very descriptive experience of my sl...
# 12  In addition, I feel like I always have to init...
# 13                   and I feel shitty and worthless.
# 14  Work hard, focus on the things that are import...
# 15        The 'not good enough' mentality bothers me.
# 16    I felt like I was the happiest person on earth.
# 17         But I ended up being emotional about this.
# 18  I lost days because of the mental exhaustion a...
# 19  Having to deal with that was one of the most t...
#
#                                                  post source_file
# 0                                 Thanks for reading.   s_99.trec
# 1   I knew they wanted a sterilized environment fo...   s_99.trec
# 2                to which I repeatedly told her "No".   s_99.trec
# 3   That he is struggling to even eat 2000 cals in...   s_99.trec
# 4             Or you have parasites, which you don't.   s_99.trec
# 5   Not the road, not the lines, just two red dots...   s_99.trec
# 6   She is gone since 2 Weeks now and i still cry ...   s_99.trec
# 7                                                       s_99.trec
# 8         it seems to come at the most random nights.   s_99.trec
# 9   I shit you not i regressed to the childhood na...   s_99.trec
# 10  This presence just feels like the space all ar...   s_99.trec
# 11                                                      s_99.trec
# 12  She doesn't seem to ever bring it up and ask m...   s_99.trec
# 13  It's completely insane and irrational, but eve...   s_99.trec
# 14  I'm not much younger and have been given many ...   s_99.trec
# 15                                                      s_99.trec
# 16    Finally, someone out there truly likes me back.   s_99.trec
# 17                             I don't even know why.   s_99.trec
# 18  Then I develop a stomach bug, when it hurts to...   s_99.trec
# 19  A week later things started getting better...t...   s_99.trec

# %%
con.execute("SELECT COUNT(*) AS n_rows FROM docs").df()
# Out:
#    n_rows
# 0   14823

# %%
OUT_CSV = "dataset2024.csv"

con.execute(f"""
COPY (
  SELECT *
  FROM docs
) TO '{OUT_CSV}' (HEADER, DELIMITER ',', QUOTE '"', ESCAPE '"');
""")

# %%
df_1 = pd.read_csv("dataset2024.csv")
df_1.head()
# Out:
#    query       docno  relevant  \
# 0     19  98002_0_18     False
# 1     11   98004_0_2      True
# 2     17   98004_0_6     False
# 3     18  98006_0_22     False
# 4     18  98006_0_26     False
#
#                                                  pre  \
# 0  I also wouldn't mind a few people to talk to a...
# 1  When I was being prepped for surgery, the nurs...
# 2  She started wheeling me down to surgery and ke...
# 3  That's when it will really set in that the who...
# 4  **TL;DR:** People are skinny because they don'...
#
#                                                 text  \
# 0                         Get my mind off of things.
# 1                             and I became agitated.
# 2                                       Feeling it?"
# 3  That's when he will realize that he really doe...
# 4  If you are skinny it's because you don't eat e...
#
#                                                 post source_file
# 0                                Thanks for reading.   s_99.trec
# 1  I knew they wanted a sterilized environment fo...   s_99.trec
# 2               to which I repeatedly told her "No".   s_99.trec
# 3  That he is struggling to even eat 2000 cals in...   s_99.trec
# 4            Or you have parasites, which you don't.   s_99.trec
